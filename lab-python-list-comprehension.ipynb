# %% [markdown]
# # Lab | List, Dict and Set Comprehension

# %% [markdown]
# ## Exercise: Managing Customer Orders Optimized with Comprehension

# %% [markdown]
# Your code should produce output similar to the following:
#
# Enter the quantity of t-shirts available:  5
# Enter the quantity of mugs available:  4
# Enter the quantity of hats available:  3
# Enter the quantity of books available:  2
# Enter the quantity of keychains available:  1
# Enter the number of customer orders:  2
# Enter the name of a product that a customer wants to order:  hat
# Enter the name of a product that a customer wants to order:  keychain
#
# Order Statistics:
# Total Products Ordered: 2
# Percentage of Unique Products Ordered: 40.0
#
# Updated Inventory:
# t-shirt: 5
# mug: 4
# hat: 2
# book: 2
# Enter the price of keychain:  5
# Enter the price of hat:  10
# Total Price: 15.0

# %% [markdown]
# ---

# %% [markdown]
# ###  Inicio lista PRODUCTO primero digo cuantos productos quiero

# %%
number_of_products = int(input("How many products do you need in your inventory"))
print(f"Has escogido un inventario con {number_of_products} productos")
# Out:
# Has escogido un inventario con 6 productos

# %% [markdown]
# ### Funcion crea lista productos

# %% [markdown]
# ```python
# new_dict = {key_expression: value_expression for item in iterable}
# ```

# %%
def create_list_products():
    list_products_original = [(input(f"Enter the name of the {x+1} product of {number_of_products}: ")) for x in range(number_of_products)]
    return list_products_original

# %%
lista_productos_original = create_list_products()
print(f"Tu inventario constara de {lista_productos_original}")
# Out:
# Tu inventario constara de ['manzanas', 'peras', 'platanos', 'sandias', 'melones', 'aguacates']

# %% [markdown]
# ### Funcion Meto Cantidades a los elementos del inventario

# %% [markdown]
# ```python
# new_dict = {key_expression: value_expression for item in iterable}
# ```

# %%
def initialize_inventory(products = lista_productos_original):
    new_inventory = {x : int(input(f"Enter the quantity of {x} availables " ))for x in products}
    return new_inventory

# %%
inventario_almacen = initialize_inventory() #este va a ser el inventario original que lo voy a guardar para no volver a escribirlo
print(f"Tu inventario inicial es este {inventario_almacen}")
# Out:
# Tu inventario inicial es este {'manzanas': 40, 'peras': 50, 'platanos': 60, 'sandias': 70, 'melones': 80, 'aguacates': 90}

# %%
import copy
inventario_trabajo= copy.deepcopy(inventario_almacen) # esta es la copia de trabajo

inventario_trabajo['manzanas']= 99 # por ver como funciona que no modifica el original
print(f"inventario_almacen {inventario_almacen}")
print(f"inventario_trabajo {inventario_trabajo}")
# Out:
# inventario_almacen {'manzanas': 40, 'peras': 50, 'platanos': 60, 'sandias': 70, 'melones': 80, 'aguacates': 90}
# inventario_trabajo {'manzanas': 99, 'peras': 50, 'platanos': 60, 'sandias': 70, 'melones': 80, 'aguacates': 90}

# %% [markdown]
# ### Funcion meto numero pedidos orden_pedido y me aseguro sean menor o igual al numero existente

# %% [markdown]
# ------- no se puede hacer con lista de comprehesion .... una lista comprehesion es una EXPRESION no un bucle de control--------------------------

# %%
pedido_no_ok = True # esto lo he creado para que el pedido no pase del numero de elementos
while pedido_no_ok == True:
    number_of_products_customer = int(input(
        f"How many products do you need in your order?\n"
        f"Tienes que meter una cantidad máxima de pedidos de {number_of_products}: "))
    if number_of_products_customer <= number_of_products:
        pedido_no_ok = False
print(f"Vas a pedir {number_of_products_customer} elementos")
# Out:
# Vas a pedir 2 elementos

# %% [markdown]
# ---

# %% [markdown]
# 2. Modify the function *get_customer_orders* so it prompts the user to enter the number of customer orders and gathers the product names using a loop and user input. Use comprehension.

# %% [markdown]
# ### Funcion meto productos distintos orden pedido

# %% [markdown]
# ```python
# new_list = [expression_ for item in original_list]
# ```

# %%
def get_customer_orders(number_of_products = number_of_products_customer):
    customer_orders_elements = [input(f"Enter the {x+1} product that a customers want to order from {inventario_almacen}:") for x in range(number_of_products_customer)]
    customer_order_quantities = [ int(input(f"Enter the quantity that a customers want to order for {element} from {inventario_almacen}:")) for element in customer_orders_elements]
    customer_order = {k:v for k,v in zip(customer_orders_elements,customer_order_quantities)}

    return customer_order

# %%
print(inventario_almacen) # es para comprobar que va bien la cosa al restar
# Out:
# {'manzanas': 40, 'peras': 50, 'platanos': 60, 'sandias': 70, 'melones': 80, 'aguacates': 90}

# %%
customer_orders_cliente = get_customer_orders()
print(f"El pedido del cliente ha sido de {customer_orders_cliente}")
# Out:
# El pedido del cliente ha sido de {'peras': 50, 'melones': 50}

# %%
pedido_cliente_trabajo= copy.deepcopy(customer_orders_cliente) # esta es la copia de trabajo

print(f"pedido_cliente_original {customer_orders_cliente}")
print(f"pedido_cliente_trabajo {pedido_cliente_trabajo}")
# Out:
# pedido_cliente_original {'peras': 50, 'melones': 50}
# pedido_cliente_trabajo {'peras': 50, 'melones': 50}

# %% [markdown]
# ---

# %% [markdown]
# print(Order_Statitisc)

# %%
print(f"inventario_original: {inventario_trabajo}")
print(f"order_customer_inventory,{pedido_cliente_trabajo}") # CON ESTOS DOS DICCIONARIOS YA SACO TODO LO QUE NECESITO
# Out:
# inventario_original: {'manzanas': 99, 'peras': 50, 'platanos': 60, 'sandias': 70, 'melones': 80, 'aguacates': 90}
# order_customer_inventory,{'peras': 50, 'melones': 50}

# %%
Total_Products_Order = len(pedido_cliente_trabajo.values()) 
print(f"Total_Products_Order : {Total_Products_Order}")
# Out:
# Total_Products_Order : 2

# %%
Total_Products_Original = len(inventario_trabajo.values())
print(f"Total_Products_Original : {Total_Products_Original}")
# Out:
# Total_Products_Original : 6

# %%
Percentage_of_Unique_Products_Ordered = round((Total_Products_Order/Total_Products_Original)*100,2)
f"Percentage_of_Unique_Products_Ordered {Percentage_of_Unique_Products_Ordered}"
# Out:
# 'Percentage_of_Unique_Products_Ordered 33.33'

# %%
print(pedido_cliente_trabajo)
# Out:
# {'peras': 50, 'melones': 50}

# %% [markdown]
# ---

# %% [markdown]
# 3. Add a new function to calculate the total price of the customer order. For each product in customer_orders, prompt the user to enter the price of that product. Use comprehension to calculate the total price. Note: assume that the user can only have 1 unit of each product.

# %%
def Price_of_Customer_Order(order):
    
    inventario_precios = {}
    for x in order.keys():
        valor = float(input(f"Mete el valor de {x}: "))
        inventario_precios[x] = valor

    precio_final = sum([inventario_precios[x]*order[x] for x in order])
    print(f"El precio final del pedido son {precio_final} euros")
    for x in order.keys():
        print(f" Has comprado {order[x]} {x} a {inventario_precios[x]} euros el kilo, total {order[x]*inventario_precios[x]} euros ")
 
     
    return

# %% [markdown]
# ---

# %% [markdown]
# 4. Modify the update_inventory function to remove the product from the inventory if its quantity becomes zero after fulfilling the customer orders. Use comprehension to filter out the products with a quantity of zero from the inventory.

# %%
print(f"inventario_inicial,{inventario_almacen}") 
print(f"pedido_cliente_trabajo,{pedido_cliente_trabajo}")
# Out:
# inventario_inicial,{'manzanas': 40, 'peras': 50, 'platanos': 60, 'sandias': 70, 'melones': 80, 'aguacates': 90}
# pedido_cliente_trabajo,{'peras': 50, 'melones': 50}

# %%
def Resta_Cantidades(inventario_inicial, pedido_cliente):
   inventario_actualizado = {
                               producto: cantidad - pedido_cliente[producto]
                               if producto in pedido_cliente
                               else cantidad                              
                               for producto, cantidad in inventario_inicial.items()
                             }
   inventario_actualizado_sin_ceros = { producto: cantidad       # no logre hacerlo en uno solo 
                                       for producto, cantidad in inventario_actualizado.items()
                                       if cantidad !=0}
   
   return inventario_actualizado_sin_ceros

# %%
inventario_trabajo = Resta_Cantidades(inventario_almacen,pedido_cliente_trabajo)
print(inventario_trabajo)
# Out:
# {'manzanas': 40, 'platanos': 60, 'sandias': 70, 'melones': 30, 'aguacates': 90}

# %% [markdown]
# 5. Print the total price of the customer order.

# %%
ticket_de_compra = Price_of_Customer_Order(pedido_cliente_trabajo)
# Out:
# El precio final del pedido son 962.5 euros
#  Has comprado 50 peras a 4.0 euros el kilo, total 200.0 euros
#  Has comprado 50 melones a 15.25 euros el kilo, total 762.5 euros
